# %% [markdown]
# # December 2022 Demo - TA1

# %% [markdown]
# - **Harvard** Domain Knowledge Graph
# - **UWisc+** xDD
# - **SKEMA** Code2FN, Text Reading and METAL, SKEMA Server, MORAE, ISA
# - **MIT**
# - **SKEMA (SIFT)** FUNMAN
# - Products

# %% [markdown]
# # SKEMA Demo

# %% [markdown]
# ## Preamble

# %%
### Code2FN
import os
from pprint import pprint
SKEMA_GOOGLE_DRIVE_ROOT = "/home/five/covid/"

### Text Reading and METAL
from automates.utils.fold import dictionary_to_gromet_json, del_nulls
from skema.text_reading.mention_linking.gromet_linker import align_and_link

# File paths (replace the data directory with your local version)
# data_directory = "/media/evo870/github/skema/skema/text_reading/mention_linking/data"
data_directory = "/home/five/other"
embedding_directory = "/home/five/other"

gromet_path = os.path.join(data_directory, "gromet", "test-auto.json")
comments_path = os.path.join(data_directory, "comments", "test-comments.json")
extractions_path = os.path.join(data_directory, "extractions", "test-extractions.json")
embeddings_path = os.path.join(embedding_directory, "embeddings.kv")

# %% [markdown]
# Running the SKEMA server
# - `cd skema/skema/skema-rs`
# - `docker-compose -f docker-compose.memgraph.yml up --build -d`
# - `cargo run --bin skema_service`

# %% [markdown]
# ## Code2FN

# %% [markdown]
# Extracting multi-module systems
# ```
# penn_chime/
# ├── __init__.py
# ├── cli.py
# ├── constants.py
# └── model
#     ├── __init__.py
#     ├── parameters.py
#     ├── sir.py
#     └── validators
#         ├── __init__.py
#         ├── base.py
#         └── validators.py
# ```
#
# System definition
# ```
# "cli.py"
# "constants.py"
# "model/parameters.py"
# "model/sir.py"
# "model/validators/base.py"
# "model/validators/validators.py"
# ```

# %%
from automates.utils.script_functions import process_file_system
from automates.program_analysis.JSON2GroMEt.json2gromet import json_to_gromet

CHIME_PATH=os.path.join(SKEMA_GOOGLE_DRIVE_ROOT, "compt-model-python")
CHIME_SYSTEM_NAME="test"
SYSTEM_ROOT_PATH=os.path.join(CHIME_PATH, CHIME_SYSTEM_NAME)
SYSTEM_FILES_PATH=os.path.join(CHIME_PATH, "system_filepaths.txt")

# process_file_system takes in the three parameters from the previous cell, and 
# generates a single GroMEt JSON file containing generated GroMEt for the whole system
process_file_system(CHIME_SYSTEM_NAME, SYSTEM_ROOT_PATH, SYSTEM_FILES_PATH)
# chime_module_collection = json_to_gromet('penn_chime--Gromet-FN-auto.json')
# Out:
# /home/five/covid/compt-model-python/test/main.py
# found numpy
# found scipy.integrate
# found matplotlib.pyplot
# Calling IdCollapsePass------------------------
#
# Calling ContainerScopePass-------------------
#
# Calling VariableVersionPass-------------------
#
# Calling GrfnVarCreationPass-------------------
#
# Calling GrfnAssignmentPass-------------------
#
# Calling LambdaExpressionPass-------------------
#
# Calling ToGrometPass-----------------------

# %%
import json # had to add this manually :/ ??
with open('test--Gromet-FN-auto.json', 'r') as f:
    chime_module_collection = json.load(f)
pprint(chime_module_collection)
# Out:
# {'executables': [],
#  'module_index': ['test.main\n'],
#  'modules': [{'attributes': [{'type': 'FN',
#                               'value': {'b': [{'function_type': 'FUNCTION',
#                                                'name': 'open'}]}},
#                              {'type': 'IMPORT',
#                               'value': {'name': 'json.load',
#                                         'src_language': 'Python',
#                                         'type': 'OTHER',
#                                         'version': '3.8'}},
#                              {'type': 'IMPORT',
#                               'value': {'name': 'json.load',
#                                         'src_language': 'Python',
#                                         'type': 'OTHER',
#                                         'version': '3.8'}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 15,
#                                                 'value': {'value': [{'slice': {'source_code_data_type': ['Python',
#                                                                                                          '3.8',
#                                                                                                          '<class '
#                                                                                                          "'str'>"],
#                                                                                'source_refs': [{'col_end': 28,
#                                                                                                 'col_start': 15,
#                                                                                                 'row_end': 17,
#                                                                                                 'row_start': 17,
#                                                                                                 'source_file_name': 'main'}],
#                                                                                'value': 'susceptible',
#                                                                                'value_type': 'List'},
#                                                                      'source_refs': [{'col_end': 29,
#                                                                                       'col_start': 2,
#                                                                                       'row_end': 17,
#                                                                                       'row_start': 17,
#                                                                                       'source_file_name': 'main'}],
#                                                                      'value': {'id': 4,
#                                                                                'name': 'compartments',
#                                                                                'source_refs': [{'col_end': 14,
#                                                                                                 'col_start': 2,
#                                                                                                 'row_end': 17,
#                                                                                                 'row_start': 17,
#                                                                                                 'source_file_name': 'main'}]}},
#                                                                     {'slice': {'source_code_data_type': ['Python',
#                                                                                                          '3.8',
#                                                                                                          '<class '
#                                                                                                          "'str'>"],
#                                                                                'source_refs': [{'col_end': 24,
#                                                                                                 'col_start': 15,
#                                                                                                 'row_end': 18,
#                                                                                                 'row_start': 18,
#                                                                                                 'source_file_name': 'main'}],
#                                                                                'value': 'exposed',
#                                                                                'value_type': 'List'},
#                                                                      'source_refs': [{'col_end': 25,
#                                                                                       'col_start': 2,
#                                                                                       'row_end': 18,
#                                                                                       'row_start': 18,
#                                                                                       'source_file_name': 'main'}],
#                                                                      'value': {'id': 4,
#                                                                                'name': 'compartments',
#                                                                                'source_refs': [{'col_end': 14,
#                                                                                                 'col_start': 2,
#                                                                                                 'row_end': 18,
#                                                                                                 'row_start': 18,
#                                                                                                 'source_file_name': 'main'}]}},
#                                                                     {'slice': {'source_code_data_type': ['Python',
#                                                                                                          '3.8',
#                                                                                                          '<class '
#                                                                                                          "'str'>"],
#                                                                                'source_refs': [{'col_end': 31,
#                                                                                                 'col_start': 15,
#                                                                                                 'row_end': 19,
#                                                                                                 'row_start': 19,
#                                                                                                 'source_file_name': 'main'}],
#                                                                                'value': 'presymptomatic',
#                                                                                'value_type': 'List'},
#                                                                      'source_refs': [{'col_end': 32,
#                                                                                       'col_start': 2,
#                                                                                       'row_end': 19,
#                                                                                       'row_start': 19,
#                                                                                       'source_file_name': 'main'}],
#                                                                      'value': {'id': 4,
#                                                                                'name': 'compartments',
#                                                                                'source_refs': [{'col_end': 14,
#                                                                                                 'col_start': 2,
#                                                                                                 'row_end': 19,
#                                                                                                 'row_start': 19,
#                                                                                                 'source_file_name': 'main'}]}},
#                                                                     {'slice': {'source_code_data_type': ['Python',
#                                                                                                          '3.8',
#                                                                                                          '<class '
#                                                                                                          "'str'>"],
#                                                                                'source_refs': [{'col_end': 37,
#                                                                                                 'col_start': 15,
#                                                                                                 'row_end': 20,
#                                                                                                 'row_start': 20,
#                                                                                                 'source_file_name': 'main'}],
#                                                                                'value': 'symptomatic_infected',
#                                                                                'value_type': 'List'},
#                                                                      'source_refs': [{'col_end': 38,
#                                                                                       'col_start': 2,
#                                                                                       'row_end': 20,
#                                                                                       'row_start': 20,
#                                                                                       'source_file_name': 'main'}],
#                                                                      'value': {'id': 4,
#                                                                                'name': 'compartments',
#                                                                                'source_refs': [{'col_end': 14,
#                                                                                                 'col_start': 2,
#                                                                                                 'row_end': 20,
#                                                                                                 'row_start': 20,
#                                                                                                 'source_file_name': 'main'}]}},
#                                                                     {'slice': {'source_code_data_type': ['Python',
#                                                                                                          '3.8',
#                                                                                                          '<class '
#                                                                                                          "'str'>"],
#                                                                                'source_refs': [{'col_end': 38,
#                                                                                                 'col_start': 15,
#                                                                                                 'row_end': 21,
#                                                                                                 'row_start': 21,
#                                                                                                 'source_file_name': 'main'}],
#                                                                                'value': 'asymptomatic_infected',
#                                                                                'value_type': 'List'},
#                                                                      'source_refs': [{'col_end': 39,
#                                                                                       'col_start': 2,
#                                                                                       'row_end': 21,
#                                                                                       'row_start': 21,
#                                                                                       'source_file_name': 'main'}],
#                                                                      'value': {'id': 4,
#                                                                                'name': 'compartments',
#                                                                                'source_refs': [{'col_end': 14,
#                                                                                                 'col_start': 2,
#                                                                                                 'row_end': 21,
#                                                                                                 'row_start': 21,
#                                                                                                 'source_file_name': 'main'}]}},
#                                                                     {'slice': {'source_code_data_type': ['Python',
#                                                                                                          '3.8',
#                                                                                                          '<class '
#                                                                                                          "'str'>"],
#                                                                                'source_refs': [{'col_end': 28,
#                                                                                                 'col_start': 15,
#                                                                                                 'row_end': 22,
#                                                                                                 'row_start': 22,
#                                                                                                 'source_file_name': 'main'}],
#                                                                                'value': 'quarantined',
#                                                                                'value_type': 'List'},
#                                                                      'source_refs': [{'col_end': 29,
#                                                                                       'col_start': 2,
#                                                                                       'row_end': 22,
#                                                                                       'row_start': 22,
#                                                                                       'source_file_name': 'main'}],
#                                                                      'value': {'id': 4,
#                                                                                'name': 'compartments',
#                                                                                'source_refs': [{'col_end': 14,
#                                                                                                 'col_start': 2,
#                                                                                                 'row_end': 22,
#                                                                                                 'row_start': 22,
#                                                                                                 'source_file_name': 'main'}]}},
#                                                                     {'slice': {'source_code_data_type': ['Python',
#                                                                                                          '3.8',
#                                                                                                          '<class '
#                                                                                                          "'str'>"],
#                                                                                'source_refs': [{'col_end': 25,
#                                                                                                 'col_start': 15,
#                                                                                                 'row_end': 23,
#                                                                                                 'row_start': 23,
#                                                                                                 'source_file_name': 'main'}],
#                                                                                'value': 'isolated',
#                                                                                'value_type': 'List'},
#                                                                      'source_refs': [{'col_end': 26,
#                                                                                       'col_start': 2,
#                                                                                       'row_end': 23,
#                                                                                       'row_start': 23,
#                                                                                       'source_file_name': 'main'}],
#                                                                      'value': {'id': 4,
#                                                                                'name': 'compartments',
#                                                                                'source_refs': [{'col_end': 14,
#                                                                                                 'col_start': 2,
#                                                                                                 'row_end': 23,
#                                                                                                 'row_start': 23,
#                                                                                                 'source_file_name': 'main'}]}},
#                                                                     {'slice': {'source_code_data_type': ['Python',
#                                                                                                          '3.8',
#                                                                                                          '<class '
#                                                                                                          "'str'>"],
#                                                                                'source_refs': [{'col_end': 26,
#                                                                                                 'col_start': 15,
#                                                                                                 'row_end': 24,
#                                                                                                 'row_start': 24,
#                                                                                                 'source_file_name': 'main'}],
#                                                                                'value': 'recovered',
#                                                                                'value_type': 'List'},
#                                                                      'source_refs': [{'col_end': 27,
#                                                                                       'col_start': 2,
#                                                                                       'row_end': 24,
#                                                                                       'row_start': 24,
#                                                                                       'source_file_name': 'main'}],
#                                                                      'value': {'id': 4,
#                                                                                'name': 'compartments',
#                                                                                'source_refs': [{'col_end': 14,
#                                                                                                 'col_start': 2,
#                                                                                                 'row_end': 24,
#                                                                                                 'row_start': 24,
#                                                                                                 'source_file_name': 'main'}]}},
#                                                                     {'slice': {'source_code_data_type': ['Python',
#                                                                                                          '3.8',
#                                                                                                          '<class '
#                                                                                                          "'str'>"],
#                                                                                'source_refs': [{'col_end': 22,
#                                                                                                 'col_start': 15,
#                                                                                                 'row_end': 25,
#                                                                                                 'row_start': 25,
#                                                                                                 'source_file_name': 'main'}],
#                                                                                'value': 'death',
#                                                                                'value_type': 'List'},
#                                                                      'source_refs': [{'col_end': 23,
#                                                                                       'col_start': 2,
#                                                                                       'row_end': 25,
#                                                                                       'row_start': 25,
#                                                                                       'source_file_name': 'main'}],
#                                                                      'value': {'id': 4,
#                                                                                'name': 'compartments',
#                                                                                'source_refs': [{'col_end': 14,
#                                                                                                 'col_start': 2,
#                                                                                                 'row_end': 25,
#                                                                                                 'row_start': 25,
#                                                                                                 'source_file_name': 'main'}]}}],
#                                                           'value_type': 'List'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'FUNCTION',
#                                                'name': 'sum'}]}},
#                              {'type': 'IMPORT',
#                               'value': {'name': 'numpy.linspace',
#                                         'src_language': 'Python',
#                                         'type': 'OTHER',
#                                         'version': '3.8'}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': -1}]}},
#                              {'type': 'IMPORT',
#                               'value': {'name': 'scipy.integrate.odeint',
#                                         'src_language': 'Python',
#                                         'type': 'OTHER',
#                                         'version': '3.8'}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': -1}]}},
#                              {'type': 'IMPORT',
#                               'value': {'name': 'matplotlib.pyplot.figure',
#                                         'src_language': 'Python',
#                                         'type': 'OTHER',
#                                         'version': '3.8'}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 28,
#                                                 'value': {'value': 'w',
#                                                           'value_type': 'List'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 31,
#                                                 'value': {'value': '#dddddd',
#                                                           'value_type': 'List'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 33,
#                                                 'value': {'value': True,
#                                                           'value_type': 'Integer'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 36,
#                                                 'value': {'value': 0.5,
#                                                           'value_type': 'AbstractFloat'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 38,
#                                                 'value': {'value': 2,
#                                                           'value_type': 'Integer'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 40,
#                                                 'value': {'value': 'Susceptible',
#                                                           'value_type': 'List'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 43,
#                                                 'value': {'value': 0.5,
#                                                           'value_type': 'AbstractFloat'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 45,
#                                                 'value': {'value': 2,
#                                                           'value_type': 'Integer'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 47,
#                                                 'value': {'value': 'Exposed',
#                                                           'value_type': 'List'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 50,
#                                                 'value': {'value': 0.5,
#                                                           'value_type': 'AbstractFloat'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 52,
#                                                 'value': {'value': 2,
#                                                           'value_type': 'Integer'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 54,
#                                                 'value': {'value': 'Presymptomatic',
#                                                           'value_type': 'List'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 57,
#                                                 'value': {'value': 0.5,
#                                                           'value_type': 'AbstractFloat'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 59,
#                                                 'value': {'value': 2,
#                                                           'value_type': 'Integer'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 61,
#                                                 'value': {'value': 'Infected',
#                                                           'value_type': 'List'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 64,
#                                                 'value': {'value': 0.5,
#                                                           'value_type': 'AbstractFloat'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 66,
#                                                 'value': {'value': 2,
#                                                           'value_type': 'Integer'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 68,
#                                                 'value': {'value': 'Asymptomatic',
#                                                           'value_type': 'List'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 71,
#                                                 'value': {'value': 0.5,
#                                                           'value_type': 'AbstractFloat'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 73,
#                                                 'value': {'value': 2,
#                                                           'value_type': 'Integer'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 75,
#                                                 'value': {'value': 'Quarantined',
#                                                           'value_type': 'List'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 78,
#                                                 'value': {'value': 0.5,
#                                                           'value_type': 'AbstractFloat'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 80,
#                                                 'value': {'value': 2,
#                                                           'value_type': 'Integer'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 82,
#                                                 'value': {'value': 'Isolated',
#                                                           'value_type': 'List'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 85,
#                                                 'value': {'value': 0.5,
#                                                           'value_type': 'AbstractFloat'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 87,
#                                                 'value': {'value': 2,
#                                                           'value_type': 'Integer'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 89,
#                                                 'value': {'value': 'Recovered',
#                                                           'value_type': 'List'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 92,
#                                                 'value': {'value': 0.5,
#                                                           'value_type': 'AbstractFloat'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 94,
#                                                 'value': {'value': 2,
#                                                           'value_type': 'Integer'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 96,
#                                                 'value': {'value': 'Death',
#                                                           'value_type': 'List'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 102,
#                                                 'value': {'value': 0,
#                                                           'value_type': 'Integer'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 104,
#                                                 'value': {'value': 0,
#                                                           'value_type': 'Integer'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 106,
#                                                 'value': {'value': True,
#                                                           'value_type': 'Integer'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 108,
#                                                 'value': {'value': 'major',
#                                                           'value_type': 'List'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
#                                         'pof': [{'box': 1, 'id': 1}],
#                                         'wfopo': [{'src': 1, 'tgt': 1}]}},
#                              {'type': 'FN',
#                               'value': {'b': [{'function_type': 'EXPRESSION'}],
#                                         'bf': [{'function_type': 'LITERAL',
#                                                 'metadata': 110,
#                                                 'value': {'value': 'w',
#                                                           'value_type': 'List'}}],
#                                         'opo': [{'box': 1, 'id': 1}],
# ...
#                                         'provenance': {'method': 'skema_code2fn_program_analysis',
#                                                        'timestamp': '2022-12-13 '
#                                                                     '17:01:38.199473'},
#                                         'source_language': 'Python',
#                                         'source_language_version': '3.8'},
#                                        {'code_file_reference_uid': '644d4902-ef17-a85a-9988-ea668ba6d634',
#                                         'col_begin': 26,
#                                         'col_end': 31,
#                                         'line_begin': 40,
#                                         'line_end': 40,
#                                         'metadata_type': 'source_code_reference',
#                                         'provenance': {'method': 'skema_code2fn_program_analysis',
#                                                        'timestamp': '2022-12-13 '
#                                                                     '17:01:38.199469'}}],
#                                       [{'code_file_reference_uid': '644d4902-ef17-a85a-9988-ea668ba6d634',
#                                         'col_begin': 14,
#                                         'col_end': 36,
#                                         'line_begin': 40,
#                                         'line_end': 40,
#                                         'metadata_type': 'source_code_reference',
#                                         'provenance': {'method': 'skema_code2fn_program_analysis',
#                                                        'timestamp': '2022-12-13 '
#                                                                     '17:01:38.199429'}}],
#                                       [{'code_file_reference_uid': '644d4902-ef17-a85a-9988-ea668ba6d634',
#                                         'col_begin': 4,
#                                         'col_end': 11,
#                                         'line_begin': 40,
#                                         'line_end': 40,
#                                         'metadata_type': 'source_code_reference',
#                                         'provenance': {'method': 'skema_code2fn_program_analysis',
#                                                        'timestamp': '2022-12-13 '
#                                                                     '17:01:38.199524'}}],
#                                       [{'code_file_reference_uid': '644d4902-ef17-a85a-9988-ea668ba6d634',
#                                         'col_begin': 14,
#                                         'col_end': 36,
#                                         'line_begin': 41,
#                                         'line_end': 41,
#                                         'metadata_type': 'source_code_reference',
#                                         'provenance': {'method': 'skema_code2fn_program_analysis',
#                                                        'timestamp': '2022-12-13 '
#                                                                     '17:01:38.199564'}}],
#                                       [{'data_type': "<class 'str'>",
#                                         'metadata_type': 'source_code_data_type',
#                                         'provenance': {'method': 'skema_code2fn_program_analysis',
#                                                        'timestamp': '2022-12-13 '
#                                                                     '17:01:38.199584'},
#                                         'source_language': 'Python',
#                                         'source_language_version': '3.8'},
#                                        {'code_file_reference_uid': '644d4902-ef17-a85a-9988-ea668ba6d634',
#                                         'col_begin': 26,
#                                         'col_end': 31,
#                                         'line_begin': 41,
#                                         'line_end': 41,
#                                         'metadata_type': 'source_code_reference',
#                                         'provenance': {'method': 'skema_code2fn_program_analysis',
#                                                        'timestamp': '2022-12-13 '
#                                                                     '17:01:38.199581'}}],
#                                       [{'code_file_reference_uid': '644d4902-ef17-a85a-9988-ea668ba6d634',
#                                         'col_begin': 14,
#                                         'col_end': 36,
#                                         'line_begin': 41,
#                                         'line_end': 41,
#                                         'metadata_type': 'source_code_reference',
#                                         'provenance': {'method': 'skema_code2fn_program_analysis',
#                                                        'timestamp': '2022-12-13 '
#                                                                     '17:01:38.199536'}}],
#                                       [{'code_file_reference_uid': '644d4902-ef17-a85a-9988-ea668ba6d634',
#                                         'col_begin': 4,
#                                         'col_end': 11,
#                                         'line_begin': 41,
#                                         'line_end': 41,
#                                         'metadata_type': 'source_code_reference',
#                                         'provenance': {'method': 'skema_code2fn_program_analysis',
#                                                        'timestamp': '2022-12-13 '
#                                                                     '17:01:38.199637'}}],
#                                       [{'data_type': 'List',
#                                         'metadata_type': 'source_code_data_type',
#                                         'provenance': {'method': 'skema_code2fn_program_analysis',
#                                                        'timestamp': '2022-12-13 '
#                                                                     '17:01:38.199654'},
#                                         'source_language': 'Python',
#                                         'source_language_version': '3.8'},
#                                        {'code_file_reference_uid': '644d4902-ef17-a85a-9988-ea668ba6d634',
#                                         'col_begin': 11,
#                                         'col_end': 5,
#                                         'line_begin': 44,
#                                         'line_end': 54,
#                                         'metadata_type': 'source_code_reference',
#                                         'provenance': {'method': 'skema_code2fn_program_analysis',
#                                                        'timestamp': '2022-12-13 '
#                                                                     '17:01:38.199650'}}],
#                                       [{'code_file_reference_uid': '644d4902-ef17-a85a-9988-ea668ba6d634',
#                                         'col_begin': 4,
#                                         'col_end': 34,
#                                         'line_begin': 33,
#                                         'line_end': 36,
#                                         'metadata_type': 'source_code_reference',
#                                         'provenance': {'method': 'skema_code2fn_program_analysis',
#                                                        'timestamp': '2022-12-13 '
#                                                                     '17:01:38.199685'}}],
#                                       [{'code_file_reference_uid': '644d4902-ef17-a85a-9988-ea668ba6d634',
#                                         'col_begin': 18,
#                                         'col_end': 22,
#                                         'line_begin': 33,
#                                         'line_end': 33,
#                                         'metadata_type': 'source_code_reference',
#                                         'provenance': {'method': 'skema_code2fn_program_analysis',
#                                                        'timestamp': '2022-12-13 '
#                                                                     '17:01:38.199694'}}],
#                                       [{'code_file_reference_uid': '644d4902-ef17-a85a-9988-ea668ba6d634',
#                                         'col_begin': 24,
#                                         'col_end': 29,
#                                         'line_begin': 33,
#                                         'line_end': 33,
#                                         'metadata_type': 'source_code_reference',
#                                         'provenance': {'method': 'skema_code2fn_program_analysis',
#                                                        'timestamp': '2022-12-13 '
#                                                                     '17:01:38.199703'}}],
#                                       [{'data_type': "<class 'int'>",
#                                         'metadata_type': 'source_code_data_type',
#                                         'provenance': {'method': 'skema_code2fn_program_analysis',
#                                                        'timestamp': '2022-12-13 '
#                                                                     '17:01:38.199729'},
#                                         'source_language': 'Python',
#                                         'source_language_version': '3.8'},
#                                        {'code_file_reference_uid': '644d4902-ef17-a85a-9988-ea668ba6d634',
#                                         'col_begin': 30,
#                                         'col_end': 31,
#                                         'line_begin': 34,
#                                         'line_end': 34,
#                                         'metadata_type': 'source_code_reference',
#                                         'provenance': {'method': 'skema_code2fn_program_analysis',
#                                                        'timestamp': '2022-12-13 '
#                                                                     '17:01:38.199726'}}],
#                                       [{'code_file_reference_uid': '644d4902-ef17-a85a-9988-ea668ba6d634',
#                                         'col_begin': 34,
#                                         'col_end': 48,
#                                         'line_begin': 34,
#                                         'line_end': 34,
#                                         'metadata_type': 'source_code_reference',
#                                         'provenance': {'method': 'skema_code2fn_program_analysis',
#                                                        'timestamp': '2022-12-13 '
#                                                                     '17:01:38.199771'}}],
#                                       [{'code_file_reference_uid': '644d4902-ef17-a85a-9988-ea668ba6d634',
#                                         'col_begin': 30,
#                                         'col_end': 48,
#                                         'line_begin': 34,
#                                         'line_end': 34,
#                                         'metadata_type': 'source_code_reference',
#                                         'provenance': {'method': 'skema_code2fn_program_analysis',
#                                                        'timestamp': '2022-12-13 '
#                                                                     '17:01:38.199786'}}],
#                                       [{'code_file_reference_uid': '644d4902-ef17-a85a-9988-ea668ba6d634',
#                                         'col_begin': 22,
#                                         'col_end': 49,
#                                         'line_begin': 34,
#                                         'line_end': 34,
#                                         'metadata_type': 'source_code_reference',
#                                         'provenance': {'method': 'skema_code2fn_program_analysis',
#                                                        'timestamp': '2022-12-13 '
#                                                                     '17:01:38.199800'}}],
#                                       [{'code_file_reference_uid': '644d4902-ef17-a85a-9988-ea668ba6d634',
#                                         'col_begin': 8,
#                                         'col_end': 49,
#                                         'line_begin': 34,
#                                         'line_end': 34,
#                                         'metadata_type': 'source_code_reference',
#                                         'provenance': {'method': 'skema_code2fn_program_analysis',
#                                                        'timestamp': '2022-12-13 '
#                                                                     '17:01:38.199712'}}],
#                                       [{'code_file_reference_uid': '644d4902-ef17-a85a-9988-ea668ba6d634',
#                                         'col_begin': 16,
#                                         'col_end': 23,
#                                         'line_begin': 35,
#                                         'line_end': 35,
#                                         'metadata_type': 'source_code_reference',
#                                         'provenance': {'method': 'skema_code2fn_program_analysis',
#                                                        'timestamp': '2022-12-13 '
#                                                                     '17:01:38.199845'}}],
#                                       [{'code_file_reference_uid': '644d4902-ef17-a85a-9988-ea668ba6d634',
#                                         'col_begin': 8,
#                                         'col_end': 23,
#                                         'line_begin': 35,
#                                         'line_end': 35,
#                                         'metadata_type': 'source_code_reference',
#                                         'provenance': {'method': 'skema_code2fn_program_analysis',
#                                                        'timestamp': '2022-12-13 '
#                                                                     '17:01:38.199831'}}],
#                                       [{'code_file_reference_uid': '644d4902-ef17-a85a-9988-ea668ba6d634',
#                                         'col_begin': 15,
#                                         'col_end': 34,
#                                         'line_begin': 36,
#                                         'line_end': 36,
#                                         'metadata_type': 'source_code_reference',
#                                         'provenance': {'method': 'skema_code2fn_program_analysis',
#                                                        'timestamp': '2022-12-13 '
#                                                                     '17:01:38.199887'}}],
#                                       [{'code_file_reference_uid': '644d4902-ef17-a85a-9988-ea668ba6d634',
#                                         'col_begin': 8,
#                                         'col_end': 34,
#                                         'line_begin': 36,
#                                         'line_end': 36,
#                                         'metadata_type': 'source_code_reference',
#                                         'provenance': {'method': 'skema_code2fn_program_analysis',
#                                                        'timestamp': '2022-12-13 '
#                                                                     '17:01:38.199904'}}]],
#               'name': 'main',
#               'schema': 'FN',
#               'schema_version': '0.1.4'}],
#  'name': 'test',
#  'schema': 'FN',
#  'schema_version': '0.1.5'}

# %% [markdown]
# ## Text Reading and Metadata Linking (METAL)

# %% [markdown]
# ![link_graph](figs/link_graph.png)

# %%
linked_gromet = align_and_link(gromet_path, comments_path, extractions_path, embeddings_path)
# Save linked gromet
with open("linked_gromet.json", 'w') as f:
    f.write(dictionary_to_gromet_json(del_nulls(linked_gromet.to_dict())))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 linked_gromet = align_and_link(gromet_path, comments_path, extractions_path, embeddings_path)
#       2 # Save linked gromet
#       3 with open("linked_gromet.json", 'w') as f:
#
# File ~/ASKEM-TA1-SKEMA-Demo-2022-12/skema/skema/text_reading/mention_linking/gromet_linker/align_comments.py:182, in align_and_link(gromet_path, comments_path, extractions_path, embeddings_path, debug)
#     180 def align_and_link(gromet_path:str, comments_path:str, extractions_path:str, embeddings_path:str, debug: bool = False):
#     181 	# Read the function network
# --> 182 	fn = json_to_gromet(gromet_path)
#     183 	# Parse the comments
#     184 	src_comments = SourceComments.from_file(comments_path)
#
# File ~/ASKEM-TA1-SKEMA-Demo-2022-12/automates/automates/program_analysis/JSON2GroMEt/json2gromet.py:37, in json_to_gromet(path)
#      35 def json_to_gromet(path):
#      36     # Read JSON from file
# ---> 37     with open(path) as f:
#      38         json_string = f.read()
#      39     json_object = json.loads(json_string)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/five/other/gromet/test-auto.json'

# %%
# Display linked gromet file
linked_gromet

# %% [markdown]
# Example of `doubling_time` units metadata:
#
# ```
# {"metadata_type": "text_units",
#  "text_extraction": {
#      "document_reference_uid": "7596863165735053645",
#      "page": 6,
#      "block": 9,
#      "char_begin": 261,
#      "char_end": 287
#  },
#  "variable_identifier": "doubling time",
#  "unit_type": "days",
#  "grounding": [
#      {"argument_name":"variable",
#       "id":"pato:0000165",
#       "description":"time",
#       "score":0.8254868},
#  ],
#  "provenance": {
#      "method": "embedding_similarity_1.0",
#      "timestamp": "2022-12-08 07:27:40.876704"
#  }
# }
# ```

# %% [markdown]
# ## SKEMA Server and FN Graph Service

# %% [markdown]
# Swagger docs for the SKEMA server REST API: http://localhost:8080/api-docs/

# %%
from IPython.display import IFrame
IFrame('http://localhost:8080/api-docs/', width=700, height=350)
# Out:
#         <iframe
#             width="700"
#             height="350"
#             src="http://localhost:8080/api-docs/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import json
from requests import get, put, post, delete
#from graphviz import Source
BASE_URL="http://localhost:8080"

# %% [markdown]
# Programmatically verify the service is running:

# %%
get(f"{BASE_URL}/ping").text
# Out:
# 'The SKEMA Rust web services are running.'

# %% [markdown]
# We can view the **memgraph web interace**, in separate brower window, open: `http://localhost:3000`

# %% [markdown]
# Load the GroMEt JSON file `CHIME_SVIIvR_core--Gromet-FN-auto.json` into the database. The operation returns the ID of the model that was just inserted - we will use this ID to query the model later.

# %%
from requests import post
with open('test--Gromet-FN-auto.json') as f:
    r = post(f"{BASE_URL}/models", json=json.loads(f.read()))
    if r.status_code == 200:
        MODEL_ID = r.json()
        print(f"Model ID: {MODEL_ID}")
    else:
        print(json.loads(r.request.body))
# Out:
# {'schema': 'FN', 'schema_version': '0.1.5', 'name': 'main', 'fn': {'b': [{'function_type': 'MODULE', 'name': 'module', 'metadata': 2}], 'bf': [{'function_type': 'LITERAL', 'value': {'value_type': 'List', 'value': './population.json'}, 'metadata': 3}, {'function_type': 'LITERAL', 'value': {'value_type': 'List', 'value': 'rb'}, 'metadata': 4}, {'function_type': 'FUNCTION', 'contents': 1, 'name': 'module.open_0', 'metadata': 5}, {'function_type': 'FUNCTION', 'contents': 2, 'metadata': 7}, {'function_type': 'LITERAL', 'value': {'value_type': 'List', 'value': './params.json'}, 'metadata': 9}, {'function_type': 'LITERAL', 'value': {'value_type': 'List', 'value': 'rb'}, 'metadata': 10}, {'function_type': 'FUNCTION', 'contents': 1, 'name': 'module.open_1', 'metadata': 11}, {'function_type': 'FUNCTION', 'contents': 3, 'metadata': 13}, {'function_type': 'EXPRESSION', 'contents': 4, 'metadata': 16}, {'function_type': 'FUNCTION', 'contents': 5, 'name': 'module.sum_0', 'metadata': 17}, {'function_type': 'FUNCTION', 'contents': 6, 'metadata': 19}, {'function_type': 'LITERAL', 'value': {'value_type': 'Integer', 'value': 0}, 'metadata': 20}, {'function_type': 'LITERAL', 'value': {'value_type': 'Integer', 'value': 160}, 'metadata': 21}, {'function_type': 'LITERAL', 'value': {'value_type': 'Integer', 'value': 160}, 'metadata': 22}, {'function_type': 'EXPRESSION', 'contents': 7, 'metadata': 23}, {'function_type': 'FUNCTION', 'contents': 8, 'metadata': 24}, {'function_type': 'EXPRESSION', 'contents': 9, 'metadata': 26}, {'function_type': 'FUNCTION', 'contents': 10, 'metadata': 27}, {'function_type': 'EXPRESSION', 'contents': 11, 'metadata': 29}, {'function_type': 'LITERAL', 'value': {'value_type': 'Integer', 'value': 111}, 'metadata': 30}, {'function_type': 'EXPRESSION', 'contents': 12, 'metadata': 32}, {'function_type': 'EXPRESSION', 'contents': 13, 'metadata': 34}, {'function_type': 'LITERAL', 'value': {'value_type': 'List', 'value': 'b'}, 'metadata': 35}, {'function_type': 'EXPRESSION', 'contents': 14, 'metadata': 37}, {'function_type': 'EXPRESSION', 'contents': 15, 'metadata': 39}, {'function_type': 'EXPRESSION', 'contents': 16, 'metadata': 41}, {'function_type': 'LITERAL', 'value': {'value_type': 'List', 'value': 'c'}, 'metadata': 42}, {'function_type': 'EXPRESSION', 'contents': 17, 'metadata': 44}, {'function_type': 'EXPRESSION', 'contents': 18, 'metadata': 46}, {'function_type': 'EXPRESSION', 'contents': 19, 'metadata': 48}, {'function_type': 'LITERAL', 'value': {'value_type': 'List', 'value': 'm'}, 'metadata': 49}, {'function_type': 'EXPRESSION', 'contents': 20, 'metadata': 51}, {'function_type': 'EXPRESSION', 'contents': 21, 'metadata': 53}, {'function_type': 'EXPRESSION', 'contents': 22, 'metadata': 55}, {'function_type': 'LITERAL', 'value': {'value_type': 'List', 'value': 'r'}, 'metadata': 56}, {'function_type': 'EXPRESSION', 'contents': 23, 'metadata': 58}, {'function_type': 'EXPRESSION', 'contents': 24, 'metadata': 60}, {'function_type': 'EXPRESSION', 'contents': 25, 'metadata': 62}, {'function_type': 'LITERAL', 'value': {'value_type': 'List', 'value': 'c'}, 'metadata': 63}, {'function_type': 'EXPRESSION', 'contents': 26, 'metadata': 65}, {'function_type': 'EXPRESSION', 'contents': 27, 'metadata': 67}, {'function_type': 'EXPRESSION', 'contents': 28, 'metadata': 69}, {'function_type': 'LITERAL', 'value': {'value_type': 'List', 'value': 'y'}, 'metadata': 70}, {'function_type': 'EXPRESSION', 'contents': 29, 'metadata': 72}, {'function_type': 'EXPRESSION', 'contents': 30, 'metadata': 74}, {'function_type': 'EXPRESSION', 'contents': 31, 'metadata': 76}, {'function_type': 'LITERAL', 'value': {'value_type': 'List', 'value': 'b'}, 'metadata': 77}, {'function_type': 'EXPRESSION', 'contents': 32, 'metadata': 79}, {'function_type': 'EXPRESSION', 'contents': 33, 'metadata': 81}, {'function_type': 'EXPRESSION', 'contents': 34, 'metadata': 83}, {'function_type': 'LITERAL', 'value': {'value_type': 'List', 'value': 'g'}, 'metadata': 84}, {'function_ ...

# %% [markdown]
# We then get the IDs of all the models in the database to double check if our model ID is among them.

# %%
get(f"{BASE_URL}/models").json()

# %% [markdown]
# Run a query to collect the names of all of the _named_ `opi`s (Output Ports) in the model.

# %%
get(f"{BASE_URL}/models/{MODEL_ID}/named_opis").json()

# %% [markdown]
# The API endpoint for **deleting** a model.

# %%
delete(f"{BASE_URL}/models/{MODEL_ID}").text

# %% [markdown]
# Get the IDs of all the models in the database again to check that the model has been deleted.

# %%
get(f"{BASE_URL}/models").json()

# %% [markdown]
# ## Model Role Analysis and Extraction (MORAE) progress

# %% [markdown]
# Developing Cypher graph queries to supplement code role pattern definitions in conjunction the Data Science Ontology

# %% [markdown]
# <div>
# <img src="figs/fn_graph_core_dynamics_legend.png" width="500"/>
# </div>

# %% [markdown]
# ## Incremental Structure Analysis (ISA) progress

# %% [markdown]
# **A quick review**: We proposed using seeded graph matching (SGM) to achieve incremental structural alignment (ISA) of equations in documents and their implementation in source code. At a high level, the procedure is as follows:
#
# 1. Create a graph representation of the equation and the code.
# 2. Construct the adjacency matrices corresponding to the above graph representations.
# 3. Apply the SGM algorithm with the two adjacency matrices as inputs.
#
# Constructing graph representations for equations and code that are suitable for the alignment procedure is a nontrivial task.
#
# Consider the S update equation in the CHIME SIR model.

# %%
from IPython.display import Image
IMAGE_PATH = 'sir.png'
Image(filename=IMAGE_PATH)

# %% [markdown]
# The presentation MathML representation of the above equation is shown below.

# %%
content = \
"""<math 
    xmlns="http://www.w3.org/1998/Math/MathML" 
    display="block" 
    title="S_{t+1} = S_t - \beta S_t I_t "
>
  <mrow>
    <msub>
      <mrow>
        <mi>S</mi>
      </mrow>
      <mrow>
        <mi>t</mi>
        <mo>+</mo>
        <mn>1</mn>
      </mrow>
    </msub>
    <mo>=</mo>
    <msub>
      <mrow>
        <mi>S</mi>
      </mrow>
      <mrow>
        <mi>t</mi>
      </mrow>
    </msub>
    <mo>-</mo>
    <mi>β</mi>
    <msub>
      <mrow>
        <mi>S</mi>
      </mrow>
      <mrow>
        <mi>t</mi>
      </mrow>
    </msub>
    <msub>
      <mrow>
        <mi>I</mi>
      </mrow>
      <mrow>
        <mi>t</mi>
      </mrow>
    </msub>
  </mrow>
</math>"""

# %% [markdown]
# We can visualize the the above MathML document using our ast-graph REST API, which returns a DOT representation of the MathML AST for visualization.

# %%
Source(
    put('http://localhost:8080/mathml/ast-graph',
        data=content.encode('utf-8')).text
)

# %% [markdown]
# However, the presentation MathML representation is only concerned with the *presentation* of the equation, rather than the *content*. In order to work with the semantic content of the equation, we must transform the presentation MathML representation into a semantically meaningful representation, using a set of heuristic rules. We call this representation the 'math expression graph' (MEG). We may come up with a better name for it later...
#
# In the cell below, we send a MathML document to the `/mathml/math-exp-graph` which automatically constructs the MEG and returns a DOT representation of it for visualization.
#
# The generated representation (shown below) encodes the semantic content of the MathML equation in a compact fashion, that can then be represented in an adjacency graph for graph alignment.

# %%
Source(
    put(
        'http://localhost:8080/mathml/math-exp-graph',
        data=content.encode('utf-8')).text
)

# %% [markdown]
# ## BiLayer Extraction

# %%
with open('CHIME_SIR_dynamics_BiLayer.json', 'r') as f:
    chime_sir_bl = json.load(f)
pprint(chime_sir_bl)

# %%
with open('CHIME_SIR_dynamics_BiLayer-metadata.json', 'r') as f:
    chime_sir_bl = json.load(f)
pprint(chime_sir_bl)

# %% [markdown]
# # Products

# %% [markdown]
# - [xDD] URL extractions from documents.
# - [xDD] Co-citation graph of documents with URLs
# - [SKEMA] Function Networks with linked metadata
# - [SKEMA] **BiLayers** with linked metadata
# - [MIT] Models with machine-readable annotations. Connections to:
#   - Ontology elements
#   - Descriptive formulas
#   - Paper passages
#   - Structured data elements
# - [SKEMA] Equation MathML
# - [SKEMA-FUNMAN] Feasible Model Parameters with quality metrics
